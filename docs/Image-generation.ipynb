# %%
#my $model = 'x/z-image-turbo:bf16';
my $model = 'x/flux2-klein:latest';
sink my $res = ollama-completion('
Make an image of android heads placed on shelf cabinet. 
Each head has a label on its forehead. 
The heads are differently looking, with different styles. 
Some fine looking, some a somewhat homemade.
The android expressions are neutral. 
', model => 'x/z-image-turbo:bf16', format => 'hash')

# %%
&from-base64.WHY

# %%
#% markdown
from-base64($res)
